# %% [markdown]
# <a href="https://colab.research.google.com/github/naonaotan/linear-regression-in-finances/blob/main/C%C3%B3pia_de_MAIN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
from google.colab import files
import os

# %%
# Montar drive
caminho_drive = "/content/drive/"
drive.mount(caminho_drive,force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
# Definir qual diretório estamos trabalhando
caminho_zip = "/content/drive/MyDrive/FAE/4/projeto_financas"
os.chdir(caminho_zip)

# %%
# Listar arquivos na pasta com os zips
lista_arquivos_zip = os.listdir(".//")
# lista_arquivos_zip

# %%
# df.dtypes

# %%
df = pd.read_excel('ibovespa_nikkei_dji(2012-2024).xlsx')
df.head()
# Out:
#    Índice        date  value_ibovespa  value_nikkei  value_dji
# 0       0  03/01/2012         59265.0           NaN   12397.38
# 1       1  04/01/2012         59365.0       8560.11   12418.42
# 2       2  05/01/2012         58546.0       8488.71   12415.70
# 3       3  06/01/2012         58600.0       8390.35   12359.92
# 4       4  09/01/2012         59083.0           NaN   12392.69

# %%
df = df.dropna()
df.head()
# Out:
#    Índice        date  value_ibovespa  value_nikkei  value_dji
# 1       1  04/01/2012         59365.0       8560.11   12418.42
# 2       2  05/01/2012         58546.0       8488.71   12415.70
# 3       3  06/01/2012         58600.0       8390.35   12359.92
# 5       5  10/01/2012         59806.0       8422.26   12462.47
# 6       6  11/01/2012         59962.0       8447.88   12449.45

# %%
df[['value_ibovespa','value_nikkei', 'value_dji']] = df[['value_ibovespa','value_nikkei', 'value_dji']].pct_change()
df = df[['date', 'value_ibovespa','value_nikkei', 'value_dji']]
df.head()
# Out:
#          date  value_ibovespa  value_nikkei  value_dji
# 1  04/01/2012             NaN           NaN        NaN
# 2  05/01/2012       -0.013796     -0.008341  -0.000219
# 3  06/01/2012        0.000922     -0.011587  -0.004493
# 5  10/01/2012        0.020580      0.003803   0.008297
# 6  11/01/2012        0.002608      0.003042  -0.001045

# %%
df[['value_nikkei', 'value_dji']] = df[['value_nikkei', 'value_dji']].shift(1)
df  = df.dropna()
df.head()
# Out:
#          date  value_ibovespa  value_nikkei  value_dji
# 3  06/01/2012        0.000922     -0.008341  -0.000219
# 5  10/01/2012        0.020580     -0.011587  -0.004493
# 6  11/01/2012        0.002608      0.003803   0.008297
# 7  12/01/2012       -0.000684      0.003042  -0.001045
# 8  13/01/2012       -0.012917     -0.007373   0.001733

# %%
# df.to_excel('df.xlsx')
# files.download('df.xlsx')
